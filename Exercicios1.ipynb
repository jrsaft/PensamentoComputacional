# %% [markdown]
# <a href="https://colab.research.google.com/github/jrsaft/PensamentoComputacional/blob/main/Exercicios1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Meu primeiro código em phyton

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = int(input("Digite um número inteiro:"))
import math
raiz = math.sqrt(x)
print("A raíz quadrada de",x,"é",raiz)
print("O quadrado de",x,"é",x ** 2)
print("A divisão é:",(x**2)/raiz)
# Out:
# Digite um número inteiro:9
# A raíz quadrada de 9 é 3.0
# O quadrado de 9 é 81
# A divisão é: 27.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
p_fab = float(input("Informe o preço de fábrica do computador:"))
imp = (p_fab *30)/100
rev = (p_fab*10)/100
p_final = p_fab + imp + rev
print("O preço final do computador é de:",p_final)
# Out:
# Informe o preço de fábrica do computador:600
# O preço final do computador é de: 840.0

# %% [markdown]
# 3. Faça um algoritmo em Python que leia três números inteiros e calcule a sua média. Ao final, o algoritmo
# deve escrever os números lidos e o resultado da média.

# %%
a = float(input("Informe o valor de a:"))
b = float(input("Informe o valor de b:"))
c = float(input("Informe o valor de c:"))

media = (a+b+c)/3

print("Para os valores de,",a,",",b,",",c,", você terá uma média de:",media )

# %% [markdown]
# 4. Fazer um algoritmo em Python que calcule o número de litros de combustível gastos em uma viagem,
# sabendo-se que o carro faz 12 km com um litro. Deverão ser lidos o tempo gasto na viagem e a velocidade
# média. Aplicar as seguintes fórmulas:
# - Distância = tempo gasto x velocidade média
# - litros gastos = distância / 12

# %%
tempo = float(input("Informe o tempo gasto na viagem:"))
velocidade = float(input("Informe a velocidade média:"))

distancia = tempo * velocidade
litros = distancia/12

print("A quantidade de litros gastos na viagem será de",litros,"litros.")
# Out:
# Informe o tempo gasto na viagem:60
# Informe a velocidade média:5.5
# A quantidade de litros gastos na viagem será de 27.5 litros.

# %% [markdown]
# 5. Faça em Python um algoritmo que leia dois números inteiros (x e y), e calcule o quociente e o resto da
# divisão de x por y e escreva os resultados.

# %%
x = int(input("Informe o valor de x:"))
y = int(input("Informe o valor de y:"))

quociente = x // y
resto = x % y

print("O quociente e o resto da divisão são, respectivamente,",quociente,",",resto,".")
# Out:
# Informe o valor de x:8
# Informe o valor de y:9
# O quociente e o resto da divisão são, respectivamente, 0 , 8 .

# %% [markdown]
# 6. Escreva em python um algoritmo que leia três números reais (a, b, c), e calcule a média aritmética. Após
# os cálculos, os resultados deverão ser escritos.

# %%
a = float(input("Informe o valor de a:"))
b = float(input("Informe o valor de b:"))
c = float(input("Informe o valor de c:"))

a = float(input("Informe o valor de a:"))
b = float(input("Informe o valor de b:"))
c = float(input("Informe o valor de c:"))

media = (a+b+c)/3

print("A média é",round(media,2))
# Out:
# Informe o valor de a:5
# Informe o valor de b:6
# Informe o valor de c:3
# Informe o valor de a:54
# Informe o valor de b:55
# Informe o valor de c:6
# A média é 38.33

# %% [markdown]
# 7. Uma loja de equipamentos de informática resolveu incentivar os seus funcionários a venderem no mês
# março. Para cada produto vendido, a loja dará uma bonificação de 1%, sobre o salário do funcionário.
# Desta forma, o funcionário que vender 10 produtos, terá um acréscimo de 10% em seu salário. Faça um
# algoritmo em Python que leia o código, o nome e o salário fixo do funcionário, além do número de
# produtos vendidos por ele no mês, e calcule o salário final do funcionário. Por fim, o algoritmo deve
# escrever o código e o nome do funcionário, juntamente com o seu salário final.

# %%
código = int(input("Informe o código do funcionário:"))
nome = (input("Informe o nome do funcionário:"))
salario = float(input("Informe o salário fixo do funcionário:"))
produtos = int(input("Informe a quantidade de produtos vendidos no mês:"))

sal_final = salario * ((produtos/100)+1)

print("O funcionário",nome,"de código",código,"receberá um salário final de",round(sal_final,2))
# Out:
# Informe o código do funcionário:85654
# Informe o nome do funcionário:leandro
# Informe o salário fixo do funcionário:1500
# Informe a quantidade de produtos vendidos no mês:8
# O funcionário leandro de código 85654 receberá um salário final de 1620.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Entradas
altura = input("Informe a altura do cilindro:")
altura = float(altura.replace(",","."))
raio = input("Informe o raio do cilindro:")
raio = float(raio.replace(",","."))

# Constantes
custo_lata = 150 # R$
litro_lata = 5 # l
litro_metro = 3 # m^2
pi = 3.14

# Calculo da area da base
area_base = pi * (raio**2)
# Calculo da area lateral
area_lateral = 2 * pi * raio * altura
# Calculo da area total
area_total = area_base + area_lateral # m^2

volume_total = area_total * altura # l

litros_necessarios = volume_total / litro_metro # l

latas_necessarias = litros_necessarios / litro_lata # latas

custo_total = latas_necessarias * custo_lata # R$

print("Para pintar este tanque será necessário:",latas_necessarias,"latas de tinta e seu custo será de: R$",custo_total)
# Out:
# Informe a altura do cilindro:12,6
# Informe o raio do cilindro:6,0
# Para pintar este tanque será necessário: 493.75872 latas de tinta e seu custo será de: R$ 74063.808

# %% [markdown]
# 9. Elabore um algoritmo em Python para calcular e escrever o preço final de um computador, sendo
# fornecido o preço de fábrica. O preço final do computador é calculado com base nos adicionais 45 % de
# imposto e 28 % de revenda sobre o preço de fábrica.

# %%
p_fab = float(input("Informe o preço de fábrica do computador:"))
imp = (p_fab *45)/100
rev = (p_fab*28)/100
p_final = p_fab + imp + rev
print("O preço final do computador é de:",p_final)
# Out:
# Informe o preço de fábrica do computador:700
# O preço final do computador é de: 1211.0

# %% [markdown]
# 10. Uma revendedora de carros usados paga aos seus funcionários vendedores, um salário fixo por mês, mais
# uma comissão para cada carro vendido. Escreva um algoritmo em Python que leia o número do vendedor,o seu salário fixo, o número de carros por ele vendidos, e o valor que recebe por carro vendido, e calcule o
# salário mensal do vendedor, escrevendo-o juntamente com o seu número de identificação.

# %%
código = int(input("Informe o número do vendedor:"))
salario = float(input("Informe o salário fixo do funcionário:"))
produto = int(input("Informe a quantidade de carros vendidos no mês:"))
valor = float(input("Informe o valor que recebe por carro vendido:"))

sal_final = salario + (produto*valor)

print("O funcionário de código",código,"receberá um salário final de",round(sal_final,2))
# Out:
# Informe o número do vendedor:0150230
# Informe o salário fixo do funcionário:1600
# Informe a quantidade de carros vendidos no mês:8
# Informe o valor que recebe por carro vendido:50
# O funcionário de código 150230 receberá um salário final de 2000.0

# %% [markdown]
# Exercício 11:

# %%
# Entradas
nome = input("Informe o nome do funcionário:")
numero_id = input("Informe o número de identificação do funcionário "+ nome +" : ")
horas_normais = float(input("Informe a quantidade de horas normais trabalhadas por "+ nome +":"))
horas_extra = float(input("Informe a quantidade de horas extras trabalhadas por "+ nome +":"))
num_dependentes = int(input("Informe o número de dependentes:"))

# Cálculo do salário bruto
salario_bruto = (horas_normais * 8) + (horas_extra * 9.5) + (num_dependentes * 2.5)

# Calculo do desconto do INSS
desconto_INSS = salario_bruto * 0.05

# Calculo do salário liquido
Salario_liquido = salario_bruto - desconto_INSS


# Saídas
print("O funcionário",nome,"com número de identificação",numero_id,"terá o salário liquído de R$",round(Salario_liquido,2))
