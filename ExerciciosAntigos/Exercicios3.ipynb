# %% [markdown]
# <a href="https://colab.research.google.com/github/jrsaft/PensamentoComputacional/blob/main/Exercicios3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Zerando as váriaveis;
x = 0

# inicio
for x in range (1,10 + 1):
  r = 9 * x
  print("9 x",x,"=",r)
# Out:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %% [markdown]
# 2. Faça um programa em Python que mostre todos os números inteiros ímpares situados na faixa
# de 1000 a 1500.

# %%
# Zerandeo as váriaveis:
x = 0

for x in range (1000,1500 + 1):
  if (x % 2) != 0:
    print(x)

# %% [markdown]
# 3. Elabore um programa em Python que calcule e escreva a soma de 10 números lidos.

# %%
# Zerando as variaveis:
x = 0
y = 0
s = 0

# Calcule e escreva a soma de 10 numeros lidos:
for x in range (1,10 + 1):
  y = float(input(f"Digite o {x}º número:"))
  s = s + y

# Saída
print("A soma dos números é:",s)
# Out:
# Digite o 1º número:2
# Digite o 2º número:6
# Digite o 3º número:3
# Digite o 4º número:5
# Digite o 5º número:2
# Digite o 6º número:0
# Digite o 7º número:0
# Digite o 8º número:2
# Digite o 9º número:08
# Digite o 10º número:96
# A soma dos números é: 124.0

# %% [markdown]
# 4. Faça um programa em Python que leia a nota de 10 alunos de uma turma. Ao final, deve ser
# escrita a média geral da turma.

# %%
# Zerando as variaveis:
x = 0
y = 0
s = 0

# Coletando as notas da turma:
for x in range (1,10 + 1):
  y = float(input(f"Digite a nota do {x}º aluno:"))
  s = s + y

# Calculando e informando a média
print("A média geral da turma é:",round(s/10,2))

# %% [markdown]
# 5. Faça um programa em Python que leia 5 números. Para cada número fornecido, escreva se
# ele é NULO, NEGATIVO ou POSITIVO.

# %%
x = 0

for x in range (1,5 + 1):
  y = float(input("Digite um número:"))
  if y == 0:
    print("Este número é nulo.")
  elif y < 0:
    print("Este número é negativo.")
  else:
    print("Este número é positivo.")

# %% [markdown]
# 6. Ler dois valores inteiros e escrever os números em sequência do menor até maior valor.

# %%
# Váriaveis:
n1 = int(input("Digite um número inteiro:"))
n2 = int(input("Digite um número inteiro:"))

# Escrevendo os números em sequência:
if n1> n2:
  print(n1,",",n2)
else:
  print(n2,",",n1)
# Out:
# Digite um número inteiro:8788787
# Digite um número inteiro:0254896
# 8788787 , 254896

# %% [markdown]
# 7. Faça um programa em Python que escreva os números pares entre 100 e 200.

# %%
# Zerandeo as váriaveis:
x = 0

for x in range (100,200 + 1):
  if (x % 2) == 0:
    print(x)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
y = int(input("Digite um número inteiro e positivo:"))

# Zerando as váriaveis;
x = 0

# inicio
for x in range (1,10 + 1):
  r = y * x
  print(y,"x",x,"=",r)
# Out:
# Digite um número inteiro e positivo:6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %% [markdown]
# 9. Escrever um programa em Python que gera os números de 1000 a 1999 e escreve aqueles
# que divididos por 11 dão um resto igual a 5.

# %%
# Zerandeo as váriaveis:
x = 0

for x in range (1000,1999 + 1):
  if (x % 11) == 5:
    print(x)

# %% [markdown]
# 10. Faça um programa em Python que leia um número qualquer (N), e realize a soma dos
# números de 1 até N. Ao final, deve-se escrever o resultado.

# %%
n = int(input("Digite um número qualquer:"))

# Zerando as variaveis:
x = 0
s = 0

# Coletando as notas da turma:
for x in range (1, n + 1):
  s = s + x

# Calculando e informando a média
print("A soma dos números é",s)
# Out:
# Digite um número qualquer:2
# A soma dos números é 3

# %% [markdown]
# 11. Faça um programa em Python para ler 10 valores inteiros. Para cada valor fornecido escreva
# uma mensagem que indica se cada valor fornecido é PAR ou ÍMPAR.

# %%
# Zerando as variaveis:
x = 0
y = 0


# Coletando os valores:
for x in range (1,10 + 1):
  y = float(input(f"Digite o {x}º número:"))
  if (y % 2) == 0:
    print("Este número é par")
  else:
    print("Este número é ímpar")

# %% [markdown]
# 12. Faça um programa em Python que leia a idade de 10 alunos, calcule e escreva a média de
# idade destes.

# %%
# Zerando as variaveis:
x = 0
y = 0
s = 0

# Coletando as idades da turma:
for x in range (1,10 + 1):
  y = int
   (input(f"Digite a idade do {x}º aluno:"))
  s = s + y

# Calculando e informando a média
print("A média geral de idade da turma é:",round(s/10))

# %% [markdown]
# 13. Faça um algoritmo em Python que leia dois valores inteiros e escreva se eles estão em ordem
# crescente, decrescente ou são iguais, após isso escreva todos os valores do menor ao maior.

# %%
# Váriaveis:
n1 = int(input("Digite um número inteiro:"))
n2 = int(input("Digite um número inteiro:"))

# Escrevendo os números em sequência:
if n1> n2:
  print("Os números estão em ordem decrescente.")
  print(n2,",",n1)
elif n1 == n2:
  print("Os números são iguais.")
  print(n1,",",n2)
else:
  print("Os números estão em ordem crescente.")
  print(n1,",",n2)
# Out:
# Digite um número inteiro:99
# Digite um número inteiro:5
# Os números estão em ordem decrescente.
# 5 , 99

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Zerando as váriaveis;
x = 0
z = 0

# inicio
for x in range (1,10 + 1):
  y = int(input("Digite um número inteiro e positivo:"))
  for z in range (1,y + 1):
   r = z * y
   print(y,"x",z,"=",r)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Zerando as váriaveis:
x = 0
cand77 = 0
cand39 = 0
cand66 = 0
voto_val = 0
voto_nao = 0
nulos = 0
branco = 0


# Opções de candidatos:
x = int(input("Digite o número do seu candidato:"))

while x != 4444444:
    if x == 77:
        cand77 = cand77 + 1
        voto_val += 1
    elif x == 39:
        cand39 = cand39 + 1
        voto_val += 1
    elif x == 66:
        cand66 = cand66 + 1
        voto_val += 1
    elif x == 0:
        branco += 1
        voto_nao += 1
    else:
        nulos += 1

    x = int(input("Digite o número do seu candidato:"))


print("A quantidade de votos para o candidato 77 foi:",cand77,",para o candidato 39 foi:",cand39,",para o candidato 66 foi:",cand66,",votos brancos:",branco,", votos nulos:",nulos,"e a quantidade de votos foi:",voto_val + voto_nao + nulos + branco,", sendo",voto_val,"votos válidos e", voto_nao,"votos inválidos.")
